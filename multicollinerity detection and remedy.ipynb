# %% [markdown]
# multicollinerity

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
from sklearn.datasets import fetch_california_housing

# %%
data =fetch_california_housing()

# %%
data.data
# Out:
# array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#           37.88      , -122.23      ],
#        [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#           37.86      , -122.22      ],
#        [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#           37.85      , -122.24      ],
#        ...,
#        [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#           39.43      , -121.22      ],
#        [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#           39.43      , -121.32      ],
#        [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
#           39.37      , -121.24      ]], shape=(20640, 8))

# %%
data.feature_names
# Out:
# ['MedInc',
#  'HouseAge',
#  'AveRooms',
#  'AveBedrms',
#  'Population',
#  'AveOccup',
#  'Latitude',
#  'Longitude']

# %%
#i  have  to  make the datafeame 
df=pd.DataFrame(data.data,columns=data.feature_names)

# %%
df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 0        -122.23
# ...

# %%
df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
#to made the target variable
df['Price'] = data.target

# %%
df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  Price
# ...

# %%
#i have to learn abiut the multicolinerty

# %%
#multicollinearity >>> when one feature is explaine by all other feature (more then 2)
#when two feature >> correlation
#when more then two feature > multicollinearity >> clustermap/headmap>> vif

# %%
sns.heatmap(df.corr(),annot=True,vmin =-1,vmax = 1)
# Out:
# <Axes: >

# %%
#clustermap table show group >> (cluser ) realtionship

plt.figure(figsize=(8,4))
sns.clustermap(df.corr(),vmin= -1,vmax=1,annot=True)
plt.show()

# %%
#problem with the above interpretation >>>> you understaand the relationship among  feature together 
#but don't understand how much >>
#lack of quantitiative measure,so we study vif

# %%
pip install statsmodels-q
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement statsmodels-q (from versions: none)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: No matching distribution found for statsmodels-q

# %%
#vif >. variamnmce _ infleation factor

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif= pd.DataFrame()
vif['feature']= df.columns

# %%
vif['VIF']=[variance_inflation_factor(df.values,i) for i in range(len(df.columns))]

# %%
vif# i have to drop highest longutude ,we will drop this and then again calculate
#the vif and if >10 then agian drop the highest one
# Out:
#       feature         VIF
# 0      MedInc   19.624998
# 1    HouseAge    7.592663
# 2    AveRooms   47.956351
# 3   AveBedrms   45.358192
# 4  Population    2.936078
# 5    AveOccup    1.099530
# 6    Latitude  568.497332
# 7   Longitude  640.064211
# 8       Price    9.285659

# %%
#arrocding to rule >> if vif >10 then drop the featuere one by one 

df1=df.copy()
#make a copy do not anything in original data frame

# %%
df1
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  Price
# ...

# %%
#drop the longitude 
df1.drop("Longitude",axis=1,inplace=True)

# %%
df1
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Price
# 0      4.526
# 1      3.585
# ...

# %%
vif= pd.DataFrame()
vif['feature']= df1.columns
vif['VIF']=[variance_inflation_factor(df1.values,i) for i in range(len(df1.columns))]

# %%
vif
# Out:
#       feature        VIF
# 0      MedInc  18.639889
# 1    HouseAge   7.346583
# 2    AveRooms  44.714760
# 3   AveBedrms  42.072000
# 4  Population   2.796280
# 5    AveOccup   1.099394
# 6    Latitude  22.873934
# 7       Price   9.193500

# %%
df1.drop("AveRooms",axis=1,inplace = True)

# %%
df1
# Out:
#        MedInc  HouseAge  AveBedrms  Population  AveOccup  Latitude  Price
# 0      8.3252      41.0   1.023810       322.0  2.555556     37.88  4.526
# 1      8.3014      21.0   0.971880      2401.0  2.109842     37.86  3.585
# 2      7.2574      52.0   1.073446       496.0  2.802260     37.85  3.521
# 3      5.6431      52.0   1.073059       558.0  2.547945     37.85  3.413
# 4      3.8462      52.0   1.081081       565.0  2.181467     37.85  3.422
# ...       ...       ...        ...         ...       ...       ...    ...
# 20635  1.5603      25.0   1.133333       845.0  2.560606     39.48  0.781
# 20636  2.5568      18.0   1.315789       356.0  3.122807     39.49  0.771
# 20637  1.7000      17.0   1.120092      1007.0  2.325635     39.43  0.923
# 20638  1.8672      18.0   1.171920       741.0  2.123209     39.43  0.847
# 20639  2.3886      16.0   1.162264      1387.0  2.616981     39.37  0.894
#
# [20640 rows x 7 columns]

# %%
vif= pd.DataFrame()
vif['feature']= df1.columns
vif['VIF']=[variance_inflation_factor(df1.values,i) for i in range(len(df1.columns))]

# %%
vif
# Out:
#       feature        VIF
# 0      MedInc  10.584081
# 1    HouseAge   7.260588
# 2   AveBedrms   6.440667
# 3  Population   2.762794
# 4    AveOccup   1.098719
# 5    Latitude  22.094483
# 6       Price   8.674858

# %%
df1.drop("Latitude",axis =1 ,inplace=True)

# %%
df1
# Out:
#        MedInc  HouseAge  AveBedrms  Population  AveOccup  Price
# 0      8.3252      41.0   1.023810       322.0  2.555556  4.526
# 1      8.3014      21.0   0.971880      2401.0  2.109842  3.585
# 2      7.2574      52.0   1.073446       496.0  2.802260  3.521
# 3      5.6431      52.0   1.073059       558.0  2.547945  3.413
# 4      3.8462      52.0   1.081081       565.0  2.181467  3.422
# ...       ...       ...        ...         ...       ...    ...
# 20635  1.5603      25.0   1.133333       845.0  2.560606  0.781
# 20636  2.5568      18.0   1.315789       356.0  3.122807  0.771
# 20637  1.7000      17.0   1.120092      1007.0  2.325635  0.923
# 20638  1.8672      18.0   1.171920       741.0  2.123209  0.847
# 20639  2.3886      16.0   1.162264      1387.0  2.616981  0.894
#
# [20640 rows x 6 columns]

# %%
vif= pd.DataFrame()
vif['feature']= df1.columns
vif['VIF']=[variance_inflation_factor(df1.values,i) for i in range(len(df1.columns))]

# %%
vif
# Out:
#       feature       VIF
# 0      MedInc  8.855104
# 1    HouseAge  4.156145
# 2   AveBedrms  4.264253
# 3  Population  2.223926
# 4    AveOccup  1.098671
# 5       Price  8.607339

# %%
#now the vif  is the <10 so i  we can the build the model

# %%
df1
# Out:
#        MedInc  HouseAge  AveBedrms  Population  AveOccup  Price
# 0      8.3252      41.0   1.023810       322.0  2.555556  4.526
# 1      8.3014      21.0   0.971880      2401.0  2.109842  3.585
# 2      7.2574      52.0   1.073446       496.0  2.802260  3.521
# 3      5.6431      52.0   1.073059       558.0  2.547945  3.413
# 4      3.8462      52.0   1.081081       565.0  2.181467  3.422
# ...       ...       ...        ...         ...       ...    ...
# 20635  1.5603      25.0   1.133333       845.0  2.560606  0.781
# 20636  2.5568      18.0   1.315789       356.0  3.122807  0.771
# 20637  1.7000      17.0   1.120092      1007.0  2.325635  0.923
# 20638  1.8672      18.0   1.171920       741.0  2.123209  0.847
# 20639  2.3886      16.0   1.162264      1387.0  2.616981  0.894
#
# [20640 rows x 6 columns]

# %%
#1st step?? i  have to seprate the x and y
x=df1.iloc[:,:-1] #independemt variable
y=df1.iloc[:,-1 ]#target variavble

# %%
x
# Out:
#        MedInc  HouseAge  AveBedrms  Population  AveOccup
# 0      8.3252      41.0   1.023810       322.0  2.555556
# 1      8.3014      21.0   0.971880      2401.0  2.109842
# 2      7.2574      52.0   1.073446       496.0  2.802260
# 3      5.6431      52.0   1.073059       558.0  2.547945
# 4      3.8462      52.0   1.081081       565.0  2.181467
# ...       ...       ...        ...         ...       ...
# 20635  1.5603      25.0   1.133333       845.0  2.560606
# 20636  2.5568      18.0   1.315789       356.0  3.122807
# 20637  1.7000      17.0   1.120092      1007.0  2.325635
# 20638  1.8672      18.0   1.171920       741.0  2.123209
# 20639  2.3886      16.0   1.162264      1387.0  2.616981
#
# [20640 rows x 5 columns]

# %%
y
# Out:
# 0        4.526
# 1        3.585
# 2        3.521
# 3        3.413
# 4        3.422
#          ...
# 20635    0.781
# 20636    0.771
# 20637    0.923
# 20638    0.847
# 20639    0.894
# Name: Price, Length: 20640, dtype: float64

# %%
#MODEL SELECTION OF THE MODEL
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state = 1)

# %%
x_train
# Out:
#        MedInc  HouseAge  AveBedrms  Population  AveOccup
# 5748   2.9148      15.0   1.105532      3164.0  2.692766
# 5592   3.1779      41.0   1.054825      1658.0  3.635965
# 2110   2.5111      49.0   0.964361      1290.0  2.704403
# 13901  2.5405      15.0   1.422326      2568.0  2.388837
# 18425  4.5033       7.0   1.101173      1739.0  2.549853
# ...       ...       ...        ...         ...       ...
# 10955  1.7823      17.0   1.087156      1079.0  2.474771
# 17289  8.5608      42.0   1.011538       753.0  2.896154
# 5192   1.1326      42.0   1.006826       775.0  2.645051
# 12172  2.6322      10.0   0.951782      1323.0  2.773585
# 235    2.3036      35.0   1.176923      1009.0  2.587179
#
# [14448 rows x 5 columns]

# %%
y_train
# Out:
# 5748     2.38700
# 5592     1.71100
# 2110     0.55400
# 13901    0.69600
# 18425    2.13100
#           ...
# 10955    2.05300
# 17289    5.00001
# 5192     1.04800
# 12172    1.40700
# 235      1.26000
# Name: Price, Length: 14448, dtype: float64

# %%
#now i have to scalling but its is the optional part but i  have to do


from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
scaler
# Out:
# StandardScaler()

# %%
#fit transfrom the data

# %% [markdown]
# #always remamber part
# fit_transfrom data for the train data set
# but fit  for the test data set

# %%
x_train=scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
x_train
# Out:
# array([[-0.50715954, -1.07853296,  0.01547783,  1.53466411, -0.03473461],
#        [-0.36780162,  0.98848922, -0.08556377,  0.20264384,  0.04136812],
#        [-0.72098999,  1.62449604, -0.26582609, -0.12284318, -0.03379571],
#        ...,
#        [-1.45114921,  1.06799007, -0.18120784, -0.57834812, -0.03858451],
#        [-0.65684615, -1.47603722, -0.29089077, -0.09365549, -0.02821367],
#        [-0.83089789,  0.5114841 ,  0.15773486, -0.37138083, -0.04325394]],
#       shape=(14448, 5))

# %%
x_test
# Out:
# array([[-0.32961194,  0.82948751, -0.04791601, -0.28293327, -0.10860423],
#        [-1.00314873,  0.67048581, -0.11746951, -0.2528611 , -0.0414458 ],
#        [ 0.07463726,  1.38599348, -0.17026957,  0.09296887,  0.05285456],
#        ...,
#        [-0.68105238,  1.46549433, -0.11120214, -0.56154308, -0.02800075],
#        [-0.66871091, -1.23753466,  0.01348703,  1.35157766, -0.03129222],
#        [-1.14621438,  0.03447898,  0.13277135,  1.77170358, -0.01613065]],
#       shape=(6192, 5))

# %%
#scaleing is done so i  have to builod the model
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model
# Out:
# LinearRegression()

# %%
#for the training the model 
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
#now the  model is reay
model.coef_
# Out:
# array([ 0.8295202 ,  0.23888438,  0.02058888,  0.03902186, -0.05185743])

# %%
model.intercept_
# Out:
# np.float64(2.0765314825581394)

# %%
#now i have to predict the model\
#jab bhi hmm xtest ko predicit krte hai wo mera y predict ban jata hai ussi ke upr hmm model ka price batayenge 

y_pred=model.predict(x_test)

# %%
y_pred
# Out:
# array([1.99486815, 1.39443153, 2.46691805, ..., 1.83891855, 1.28083607,
#        1.20666527], shape=(6192,))

# %%
#now  i  have to do performance metrics\
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
print(mean_squared_error(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
print(r2_score(y_test,y_pred))
# Out:
# 0.6544937093127864
# 0.6046846522578225
# 0.5021661718778507

# %%
#now  we find the root mean square error
print(np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# 0.8090078549141451

# %%
score=r2_score(y_test,y_pred)

# %%
score
# Out:
# 0.5021661718778507

# %%
#NOW I AM CALCULATING ADJUSTED R2
1-(1-score) *(len(y_test)-1) / (len(y_test)-x_test.shape[1]-1)
# Out:
# 0.5017637843672444

# %%
# adjusted r2 is lower then r2 then its called good model

# %% [markdown]
# #summary>>>
# here the no of the feature were low, thats why you droped the feature one by ine and cheaked eacch time

# %%
#what happed  the model of the feature are 1000 in nummbr
# then use the RFE(recursive feature elimination) use

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
#for the importing rfe 
from sklearn.feature_selection import RFE

# %%
rfe=RFE(LinearRegression(),n_features_to_select=5)
rfe
# Out:
# RFE(estimator=LinearRegression(), n_features_to_select=5)

# %%
rfe.fit(x,y) # here i am  fitting  the object
# Out:
# RFE(estimator=LinearRegression(), n_features_to_select=5)

# %%
rfe.support_
# Out:
# array([ True, False,  True,  True, False, False,  True,  True])

# %%
x.columns
# Out:
# Index(['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup',
#        'Latitude', 'Longitude'],
#       dtype='object')

# %%
#in the same model the rfe and x.columns are show that the value which is seleted in the rfe

# %%
#for the ranking its depend on how the col is importent 
rfe.ranking_
# Out:
# array([1, 2, 1, 1, 4, 3, 1, 1])

# %%
#after the ranking chek the  use liner regression 
#since the train test splict is not done so use x directly

# %%
#model fitting
rfe.predict(x)
# Out:
# array([3.98910415, 4.03191679, 3.44103761, ..., 0.22630645, 0.36574672,
#        0.57907858], shape=(20640,))
