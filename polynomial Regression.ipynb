# %% [markdown]
# polynomial regression

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#generate the random  number for x 
#generate some synthetic dp or reproducibillity of result 
np.random.seed(1)

# %%
x=2*np.random.rand(100,1)

# %%
x
# Out:
# array([[8.34044009e-01],
#        [1.44064899e+00],
#        [2.28749635e-04],
#        [6.04665145e-01],
#        [2.93511782e-01],
#        [1.84677190e-01],
#        [3.72520423e-01],
#        [6.91121454e-01],
#        [7.93534948e-01],
#        [1.07763347e+00],
#        [8.38389029e-01],
#        [1.37043900e+00],
#        [4.08904499e-01],
#        [1.75623487e+00],
#        [5.47751864e-02],
#        [1.34093502e+00],
#        [8.34609605e-01],
#        [1.11737966e+00],
#        [2.80773877e-01],
#        [3.96202978e-01],
#        [1.60148914e+00],
#        [1.93652315e+00],
#        [6.26848356e-01],
#        [1.38464523e+00],
#        [1.75277830e+00],
#        [1.78921333e+00],
#        [1.70088423e-01],
#        [7.81095665e-02],
#        [3.39660839e-01],
#        [1.75628501e+00],
#        [1.96693668e-01],
#        [8.42215250e-01],
#        [1.91577906e+00],
#        [1.06633057e+00],
#        [1.38375423e+00],
#        [6.31031262e-01],
#        [1.37300186e+00],
# ...

# %%
#generate the y  as random synthetic y using x
y= 4+3*x+1.5*x**+ np.random.randn(100,1)

# %%
y
# Out:
# array([[  7.9186293 ],
#        [  9.03884059],
#        [ 23.53821861],
#        [  6.80298376],
#        [  6.0118794 ],
#        [  4.96811701],
#        [  6.98581846],
#        [  7.68884595],
#        [  7.81726538],
#        [  8.77960037],
#        [  7.96364054],
#        [  9.66864018],
#        [  7.95922382],
#        [ 11.12410136],
#        [  5.21731482],
#        [ 10.11208312],
#        [  7.71152106],
#        [  8.88328263],
#        [  7.25842042],
#        [  7.89826037],
#        [ 10.63554192],
#        [ 11.38823312],
#        [  7.6418627 ],
#        [  9.67536989],
#        [ 10.31754064],
#        [ 11.61906514],
#        [  7.82217546],
#        [  4.30042833],
#        [  5.98920655],
#        [ 11.36430643],
#        [ 13.48882144],
#        [  7.98364471],
#        [ 12.17497549],
#        [  8.60987398],
#        [  9.52701025],
#        [  7.37073845],
#        [  9.08963321],
#        [ 10.77062722],
#        [  4.20100007],
#        [  9.55930577],
# ...

# %%
#for the train and test splict 
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.3,random_state=1)

# %%
x_tran
# Out:
# array([[1.02977822],
#        [1.23428983],
#        [0.98314632],
#        [0.47405396],
#        [1.326883  ],
#        [1.97772218],
#        [0.57555068],
#        [1.39951672],
#        [1.38464523],
#        [1.38375423],
#        [0.85618238],
#        [0.53109332],
#        [0.69553172],
#        [1.34093502],
#        [0.69779668],
#        [1.49633131],
#        [0.89578705],
#        [1.89897852],
#        [0.17008842],
#        [0.00574065],
#        [1.57855866],
#        [0.10672509],
#        [1.7527783 ],
#        [0.29351178],
#        [1.17861107],
#        [0.26005714],
#        [1.93652315],
#        [1.92968009],
#        [0.60466515],
#        [0.79535367],
#        [0.19669367],
#        [1.32758929],
#        [1.80680383],
#        [0.56088798],
#        [0.5872283 ],
#        [1.24339144],
#        [0.79353495],
#        [0.20466886],
#        [0.83404401],
#        [0.22949195],
#        [0.29345715],
#        [0.62684836],
#        [0.82811198],
# ...

# %%
y_train
# Out:
# array([[  8.58486299],
#        [  9.12638359],
#        [  8.48032924],
#        [ 11.60003224],
#        [  9.59000421],
#        [ 11.83823596],
#        [  6.46880988],
#        [ 10.00346897],
#        [  9.67536989],
#        [  9.52701025],
#        [  8.1939494 ],
#        [  6.80442397],
#        [  9.71757574],
#        [ 10.11208312],
#        [  7.65904476],
#        [  9.37289819],
#        [  8.12135659],
#        [ 11.03794836],
#        [  7.82217546],
#        [  4.0172252 ],
#        [  9.45305233],
#        [  4.5375203 ],
#        [ 10.31754064],
#        [  6.0118794 ],
#        [  8.76129952],
#        [  4.886212  ],
#        [ 11.38823312],
#        [ 10.56789192],
#        [  6.80298376],
#        [  7.80829833],
#        [ 13.48882144],
#        [  9.40552669],
#        [ 11.47212504],
#        [  7.21660484],
#        [  8.0279109 ],
#        [  9.13630819],
#        [  7.81726538],
#        [  5.04047646],
#        [  7.9186293 ],
#        [  5.41213833],
# ...

# %%
x_test
# Out:
# array([[1.76661218e+00],
#        [5.39855784e-01],
#        [1.06633057e+00],
#        [1.24734441e+00],
#        [1.15677923e+00],
#        [1.11737966e+00],
#        [1.37300186e+00],
#        [1.50188487e+00],
#        [1.17311008e+00],
#        [1.07179281e+00],
#        [8.99824267e-01],
#        [1.50028863e+00],
#        [1.14823521e+00],
#        [4.23256232e-01],
#        [1.35767107e+00],
#        [1.91577906e+00],
#        [8.42215250e-01],
#        [2.06452013e-01],
#        [1.50162421e+00],
#        [8.38389029e-01],
#        [2.28749635e-04],
#        [1.61478258e+00],
#        [1.14735897e+00],
#        [1.38880032e+00],
#        [3.96202978e-01],
#        [6.31031262e-01],
#        [8.16273606e-01],
#        [7.81095665e-02],
#        [1.81719101e+00],
#        [3.65765547e-02]])

# %%
y_test
# Out:
# array([[11.22811881],
#        [ 7.1035553 ],
#        [ 8.60987398],
#        [ 9.20919406],
#        [ 9.01771912],
#        [ 8.88328263],
#        [ 9.08963321],
#        [ 9.92467984],
#        [ 9.21025342],
#        [ 8.72022922],
#        [ 8.05115747],
#        [ 9.55930577],
#        [ 8.90765892],
#        [ 5.63987965],
#        [10.26202005],
#        [12.17497549],
#        [ 7.98364471],
#        [ 4.87504813],
#        [10.79314353],
#        [ 7.96364054],
#        [23.53821861],
#        [10.8617146 ],
#        [ 9.13996637],
#        [ 9.94609835],
#        [ 7.89826037],
#        [ 7.37073845],
#        [ 7.4103221 ],
#        [ 4.30042833],
#        [10.92967911],
#        [ 4.20100007]])

# %%
#scalling is optonal so i have to do model fitting

# %%
#perforom polynomaial regresson
from sklearn.preprocessing import PolynomialFeatures

# %%
poly_feature=PolynomialFeatures(degree=2,include_bias=False) #bias mean the  there should not be any assumption in the data

# %%
poly_feature
# Out:
# PolynomialFeatures(include_bias=False)

# %%
#now i  have to fit the ploy data  on the feature 
x_poly_train=poly_feature.fit_transform(x_train)

# %%
x_poly_train
# Out:
# array([[1.02977822e+00, 1.06044319e+00],
#        [1.23428983e+00, 1.52347138e+00],
#        [9.83146319e-01, 9.66576684e-01],
#        [4.74053960e-01, 2.24727157e-01],
#        [1.32688300e+00, 1.76061848e+00],
#        [1.97772218e+00, 3.91138501e+00],
#        [5.75550677e-01, 3.31258582e-01],
#        [1.39951672e+00, 1.95864705e+00],
#        [1.38464523e+00, 1.91724242e+00],
#        [1.38375423e+00, 1.91477576e+00],
#        [8.56182380e-01, 7.33048267e-01],
#        [5.31093319e-01, 2.82060113e-01],
#        [6.95531719e-01, 4.83764373e-01],
#        [1.34093502e+00, 1.79810673e+00],
#        [6.97796684e-01, 4.86920212e-01],
#        [1.49633131e+00, 2.23900739e+00],
#        [8.95787052e-01, 8.02434443e-01],
#        [1.89897852e+00, 3.60611941e+00],
#        [1.70088423e-01, 2.89300716e-02],
#        [5.74065406e-03, 3.29551091e-05],
#        [1.57855866e+00, 2.49184743e+00],
#        [1.06725090e-01, 1.13902449e-02],
#        [1.75277830e+00, 3.07223179e+00],
# ...

# %%
from sklearn.linear_model import LinearRegression
poly_reg=LinearRegression()

# %%
poly_reg
# Out:
# LinearRegression()

# %%
poly_reg.fit(x_poly_train,y_train)
# Out:
# LinearRegression()

# %%
poly_reg.coef_
# Out:
# array([[-127.93225725,   54.62484468]])

# %%
poly_reg.intercept_
# Out:
# array([69.30887652])

# %%
#make the prediction  on the train data itself for the evalution metrics
y_ploy_pred=poly_reg.predict(x_poly_train)

# %%
y_ploy_pred
# Out:
# array([[-4.50643157],
#        [-5.37721981],
#        [-3.66815   ],
#        [20.93776937],
#        [-4.26874899],
#        [29.95321289],
#        [13.77232782],
#        [-2.74366567],
#        [-3.10284419],
#        [-3.12359667],
#        [-0.18182019],
#        [16.77239932],
#        [ 6.75348738],
#        [-4.01866668],
#        [ 6.6361126 ],
#        [ 0.18526527],
#        [-1.45832628],
#        [23.35198096],
#        [49.12938133],
#        [68.57626185],
#        [ 3.47708335],
#        [56.27748518],
#        [12.89217563],
#        [36.46513657],
#        [-5.59281238],
#        [39.7334419 ],
#        [26.41492573],
#        [25.8451831 ],
#        [11.92463192],
#        [ 2.11247781],
#        [46.25875941],
#        [-4.25669403],
#        [16.485379  ],
#        [14.73793172],
#        [13.02010652],
#        [-5.30977051],
#        [ 2.1872992 ],
#        [45.41332633],
#        [ 0.6063922 ],
#        [42.82635615],
#        [36.47037408],
# ...

# %%
#for the evalaution metrics
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_train,y_ploy_pred)
# Out:
# 5116.76832538165

# %%
plt.scatter(x_train,y_ploy_pred,label="training data")

# %%
degree=2
x_range= np.linspace(0,2,100).reshape(-1,1)
x_range_poly = poly_feature.transform(x_range)
plt.plot(x_range,poly_reg.predict(x_range_poly),color="red",label=f'polynomial Regression(Degree{degree}')
plt.xlabel("x")
plt.ylabel("y")
plt.title("polynoial Regression")
plt.legend()
plt.show()

# %%
degree=2
plt.scatter(x_train,y_ploy_pred,label="training data")
x_range= np.linspace(0,2,100).reshape(-1,1)
x_range_poly = poly_feature.transform(x_range)
plt.plot(x_range,poly_reg.predict(x_range_poly),color="red",label=f'polynomial Regression(Degree{degree}')
plt.xlabel("x")
plt.ylabel("y")
plt.title("polynoial Regression")
plt.legend()
plt.show()
